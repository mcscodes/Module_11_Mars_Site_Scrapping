# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Extract all rows of data
table_rows = soup.find_all('tr', class_="data-row")
table_rows
# Out:
# [<tr class="data-row">
#  <td>2</td>
#  <td>2012-08-16</td>
#  <td>10</td>
#  <td>155</td>
#  <td>6</td>
#  <td>-75.0</td>
#  <td>739.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>13</td>
#  <td>2012-08-17</td>
#  <td>11</td>
#  <td>156</td>
#  <td>6</td>
#  <td>-76.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>24</td>
#  <td>2012-08-18</td>
#  <td>12</td>
#  <td>156</td>
#  <td>6</td>
#  <td>-76.0</td>
#  <td>741.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>35</td>
#  <td>2012-08-19</td>
#  <td>13</td>
#  <td>157</td>
#  <td>6</td>
#  <td>-74.0</td>
#  <td>732.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>46</td>
#  <td>2012-08-20</td>
#  <td>14</td>
#  <td>157</td>
#  <td>6</td>
#  <td>-74.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>57</td>
#  <td>2012-08-21</td>
#  <td>15</td>
#  <td>158</td>
#  <td>6</td>
#  <td>-78.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>68</td>
#  <td>2012-08-22</td>
# ...

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Received help from Xpert Learning Assistant 
# Create an empty list
data_dictionary = []

# Loop through the scraped data to create a list of rows
for row in table_rows:
    cells = row.find_all('td')
    data_dictionary.append({
        "id": cells[0].text,
        "terrestrial_date": cells[1].text,
        "sol": int(cells[2].text),
        "ls": float(cells[3].text),
        "month": cells[4].text,
        "min_temp": float(cells[5].text),
        "pressure": float(cells[6].text)
    })

data_dictionary
# Out:
# [{'id': '2',
#   'terrestrial_date': '2012-08-16',
#   'sol': 10,
#   'ls': 155.0,
#   'month': '6',
#   'min_temp': -75.0,
#   'pressure': 739.0},
#  {'id': '13',
#   'terrestrial_date': '2012-08-17',
#   'sol': 11,
#   'ls': 156.0,
#   'month': '6',
#   'min_temp': -76.0,
#   'pressure': 740.0},
#  {'id': '24',
#   'terrestrial_date': '2012-08-18',
#   'sol': 12,
#   'ls': 156.0,
#   'month': '6',
#   'min_temp': -76.0,
#   'pressure': 741.0},
#  {'id': '35',
#   'terrestrial_date': '2012-08-19',
#   'sol': 13,
#   'ls': 157.0,
#   'month': '6',
#   'min_temp': -74.0,
#   'pressure': 732.0},
#  {'id': '46',
#   'terrestrial_date': '2012-08-20',
#   'sol': 14,
#   'ls': 157.0,
#   'month': '6',
#   'min_temp': -74.0,
#   'pressure': 740.0},
#  {'id': '57',
#   'terrestrial_date': '2012-08-21',
#   'sol': 15,
#   'ls': 158.0,
#   'month': '6',
#   'min_temp': -78.0,
#   'pressure': 740.0},
#  {'id': '68',
#   'terrestrial_date': '2012-08-22',
#   'sol': 16,
#   'ls': 158.0,
# ...

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
columns = ["id", "terrestrial_date", "sol", "ls", "month", "min_temp", "pressure"]
mars_weather_df = pd.DataFrame(data_dictionary, columns=columns)

# %%
# Confirm DataFrame was created successfully
mars_weather_df
# Out:
#         id terrestrial_date   sol     ls month  min_temp  pressure
# 0        2       2012-08-16    10  155.0     6     -75.0     739.0
# 1       13       2012-08-17    11  156.0     6     -76.0     740.0
# 2       24       2012-08-18    12  156.0     6     -76.0     741.0
# 3       35       2012-08-19    13  157.0     6     -74.0     732.0
# 4       46       2012-08-20    14  157.0     6     -74.0     740.0
# ...    ...              ...   ...    ...   ...       ...       ...
# 1862  1889       2018-02-23  1973  133.0     5     -78.0     730.0
# 1863  1892       2018-02-24  1974  134.0     5     -77.0     729.0
# 1864  1894       2018-02-25  1975  134.0     5     -76.0     729.0
# 1865  1893       2018-02-26  1976  135.0     5     -77.0     728.0
# 1866  1895       2018-02-27  1977  135.0     5     -77.0     727.0
#
# [1867 rows x 7 columns]

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
data_types = mars_weather_df.dtypes
data_types
# Out:
# id                   object
# terrestrial_date     object
# sol                   int64
# ls                  float64
# month                object
# min_temp            float64
# pressure            float64
# dtype: object

# %%
# Change data types for data analysis
mars_weather_df['terrestrial_date'] = pd.to_datetime(mars_weather_df['terrestrial_date'])
mars_weather_df['ls'] = mars_weather_df['ls'].astype(int)
mars_weather_df['month'] = mars_weather_df['month'].astype(int)

# %%
# Confirm type changes were successful by examining data types again
mars_weather_df.dtypes
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                          int64
# ls                           int64
# month                        int64
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
unique_month_count = mars_weather_df['month'].value_counts().sort_index()
print(unique_month_count)
# Out:
# month
# 1     174
# 2     178
# 3     192
# 4     194
# 5     149
# 6     147
# 7     142
# 8     141
# 9     134
# 10    112
# 11    138
# 12    166
# Name: count, dtype: int64

# %% [markdown]
# **There are 12 unique months on Mars.**

# %%
# 2. How many Martian days' worth of data are there?
days_of_data = mars_weather_df['terrestrial_date'].count()
print(days_of_data)
# Out:
# 1867

# %% [markdown]
# **There are 1867 Martian days' worth of data.**

# %%
# 3. What is the average low temperature by month?
average_low_temp = mars_weather_df.groupby('month')['min_temp'].mean()
print(average_low_temp)
# Out:
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %% [markdown]
# **See above.**

# %%
# Plot the average temperature by month
average_low_temp_df = pd.DataFrame(average_low_temp).reset_index()
average_low_temp_df.columns = ['Month', 'Average Temperature']
average_low_temp_df.plot(x='Month', y='Average Temperature', kind='bar', color='blue')
plt.xlabel('Month')
plt.ylabel('Temperature in Celsius')
plt.title('Average Low Temperature by Month on Mars')
plt.xticks(range(0, 13))
plt.show()

# %%
# Identify the coldest and hottest months in Curiosity's location
# Sort the DataFrame by the "Average Temperature" column in acscending order
average_low_temp_df = average_low_temp_df.sort_values(by='Average Temperature', ascending=True)

# Plot the sorted DataFrame
average_low_temp_df.plot(x='Month', y='Average Temperature', kind='bar', color='blue')
plt.xlabel('Month')
plt.ylabel('Temperature in Celsius')
plt.title('Average Low Temperature by Month on Mars - Sorted')
plt.xticks(range(0, 13))
plt.show()

# %% [markdown]
# **The month with the lowest average temperature is month 3 (on Earth, this month is known as "March"). The month with the highest average temperature is month 8 (on Earth, this month is known as "August").**

# %%
# 4. Average pressure by Martian month
average_pressure = mars_weather_df.groupby('month')['pressure'].mean()
print(average_pressure)
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month
average_pressure_df = pd.DataFrame(average_pressure).reset_index()
average_pressure_df.columns = ['Month', 'Average Pressure']
average_pressure_df = average_pressure_df.sort_values(by='Average Pressure', ascending=True)
average_pressure_df.plot(x='Month', y='Average Pressure', kind='bar', color='blue')
plt.xlabel('Month')
plt.ylabel('Atmospheric Pressure')
plt.title('Average Pressure by Month on Mars')
plt.xticks(range(0, 13))
plt.show()

# %% [markdown]
# **The month with the lowest average pressure is month 6 (on Earth, this month is known as "June"). The month with the highest average pressure is month 9 (on Earth, this month is known as "September").**

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?

mars_weather_df.plot(x='id', y='min_temp', color='blue', linestyle='-')
plt.xlabel('Number of terrestrial days')
plt.ylabel('Minimum temperature')
plt.title('Daily Minimum Temperature on Mars')
plt.grid(True)
plt.show()

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
mars_weather_df.to_csv('output_file.csv', index=False)

# %%
browser.quit()
